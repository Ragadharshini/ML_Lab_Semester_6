# %% [markdown]
# Author : Mukesh T P
#
# Exercise 3

# %%
#import statements

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# Use the dataset, perform necessary pre-processing and build a logistic regression model. divide the train data itself into 70-30 ratio and print the performance metrics

# %%
data = pd.read_csv('telecom_customer_churn.csv')
data
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 6584  9986-BONCE  Female   36      No                     0     Fallbrook
# 6585  9987-LUTYD  Female   20      No                     0       La Mesa
# 6586  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 6587  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 6588  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# 0        93225  34.827662 -118.999073                    2  ...
# 1        91206  34.162515 -118.203869                    0  ...
# 2        92627  33.645672 -117.922613                    0  ...
# 3        94553  38.014457 -122.115432                    1  ...
# 4        93010  34.227846 -119.079903                    3  ...
# ...        ...        ...         ...                  ...  ...
# 6584     92028  33.362575 -117.299644                    0  ...
# 6585     91941  32.759327 -116.997260                    0  ...
# 6586     95367  37.734971 -120.954271                    1  ...
# 6587     92075  33.001813 -117.263628                    5  ...
# 6588     96125  39.600599 -120.636358                    1  ...
#
#        Payment Method Monthly Charge Total Charges  Total Refunds  \
# 0         Credit Card          65.60        593.30           0.00
# 1         Credit Card          -4.00        542.40          38.33
# 2     Bank Withdrawal          73.90        280.85           0.00
# 3     Bank Withdrawal          98.00       1237.85           0.00
# 4         Credit Card          83.90        267.40           0.00
# ...               ...            ...           ...            ...
# 6584  Bank Withdrawal          20.95         85.50           0.00
# 6585      Credit Card          55.15        742.90           0.00
# 6586  Bank Withdrawal          85.10       1873.70           0.00
# 6587      Credit Card          67.85       4627.65           0.00
# 6588  Bank Withdrawal          59.00       3707.60           0.00
#
#      Total Extra Data Charges Total Long Distance Charges Total Revenue  \
# 0                           0                      381.51        974.81
# 1                          10                       96.21        610.28
# 2                           0                      134.60        415.45
# 3                           0                      361.66       1599.51
# 4                           0                       22.14        289.54
# ...                       ...                         ...           ...
# 6584                        0                        8.04         93.54
# 6585                        0                      606.84       1349.74
# 6586                        0                      356.40       2230.10
# 6587                        0                      142.04       4769.69
# 6588                        0                        0.00       3707.60
#
#       Customer Status   Churn Category                   Churn Reason
# 0                   1              NaN                            NaN
# 1                   1              NaN                            NaN
# 2                   0       Competitor  Competitor had better devices
# 3                   0  Dissatisfaction        Product dissatisfaction
# 4                   0  Dissatisfaction            Network reliability
# ...               ...              ...                            ...
# 6584                0       Competitor   Competitor made better offer
# 6585                1              NaN                            NaN
# 6586                0  Dissatisfaction        Product dissatisfaction
# 6587                1              NaN                            NaN
# 6588                1              NaN                            NaN
#
# [6589 rows x 38 columns]

# %%
data = data.drop(['Customer ID','City'], axis = 1)
score = data.isnull().sum()
for i in data.columns:
    if (score[i] > 1000):
        data = data.drop(i, axis=1)

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#       Gender  Age Married  Number of Dependents  Zip Code   Latitude  \
# 0     Female   37     Yes                     0     93225  34.827662
# 1       Male   46      No                     0     91206  34.162515
# 2       Male   50      No                     0     92627  33.645672
# 3       Male   78     Yes                     0     94553  38.014457
# 4     Female   75     Yes                     0     93010  34.227846
# ...      ...  ...     ...                   ...       ...        ...
# 6583  Female   53      No                     0     93628  36.807595
# 6584  Female   36      No                     0     92028  33.362575
# 6585  Female   20      No                     0     91941  32.759327
# 6586    Male   40     Yes                     0     95367  37.734971
# 6587    Male   21     Yes                     0     92075  33.001813
#
#        Longitude  Number of Referrals  Tenure in Months Phone Service  ...  \
# 0    -118.999073                    2                 9           Yes  ...
# 1    -118.203869                    0                 9           Yes  ...
# 2    -117.922613                    0                 4           Yes  ...
# 3    -122.115432                    1                13           Yes  ...
# 4    -119.079903                    3                 3           Yes  ...
# ...          ...                  ...               ...           ...  ...
# 6583 -118.901544                    0                 1           Yes  ...
# 6584 -117.299644                    0                 4           Yes  ...
# 6585 -116.997260                    0                13           Yes  ...
# 6586 -120.954271                    1                22           Yes  ...
# 6587 -117.263628                    5                67           Yes  ...
#
#             Contract Paperless Billing   Payment Method Monthly Charge  \
# 0           One Year               Yes      Credit Card          65.60
# 1     Month-to-Month                No      Credit Card          -4.00
# 2     Month-to-Month               Yes  Bank Withdrawal          73.90
# 3     Month-to-Month               Yes  Bank Withdrawal          98.00
# 4     Month-to-Month               Yes      Credit Card          83.90
# ...              ...               ...              ...            ...
# 6583  Month-to-Month               Yes      Credit Card          70.15
# 6584  Month-to-Month                No  Bank Withdrawal          20.95
# 6585        One Year                No      Credit Card          55.15
# 6586  Month-to-Month               Yes  Bank Withdrawal          85.10
# 6587        Two Year                No      Credit Card          67.85
#
#      Total Charges Total Refunds  Total Extra Data Charges  \
# 0           593.30          0.00                         0
# 1           542.40         38.33                        10
# 2           280.85          0.00                         0
# 3          1237.85          0.00                         0
# 4           267.40          0.00                         0
# ...            ...           ...                       ...
# 6583         70.15          0.00                         0
# 6584         85.50          0.00                         0
# 6585        742.90          0.00                         0
# 6586       1873.70          0.00                         0
# 6587       4627.65          0.00                         0
#
#       Total Long Distance Charges  Total Revenue  Customer Status
# 0                          381.51         974.81                1
# 1                           96.21         610.28                1
# 2                          134.60         415.45                0
# 3                          361.66        1599.51                0
# 4                           22.14         289.54                0
# ...                           ...            ...              ...
# 6583                        42.09         112.24                0
# 6584                         8.04          93.54                0
# 6585                       606.84        1349.74                1
# 6586                       356.40        2230.10                0
# 6587                       142.04        4769.69                1
#
# [5945 rows x 23 columns]

# %%
data.replace({'No': 0, 'Yes': 1}, inplace=True)
data
# Out:
#       Gender  Age  Married  Number of Dependents  Zip Code   Latitude  \
# 0     Female   37        1                     0     93225  34.827662
# 1       Male   46        0                     0     91206  34.162515
# 2       Male   50        0                     0     92627  33.645672
# 3       Male   78        1                     0     94553  38.014457
# 4     Female   75        1                     0     93010  34.227846
# ...      ...  ...      ...                   ...       ...        ...
# 6583  Female   53        0                     0     93628  36.807595
# 6584  Female   36        0                     0     92028  33.362575
# 6585  Female   20        0                     0     91941  32.759327
# 6586    Male   40        1                     0     95367  37.734971
# 6587    Male   21        1                     0     92075  33.001813
#
#        Longitude  Number of Referrals  Tenure in Months  Phone Service  ...  \
# 0    -118.999073                    2                 9              1  ...
# 1    -118.203869                    0                 9              1  ...
# 2    -117.922613                    0                 4              1  ...
# 3    -122.115432                    1                13              1  ...
# 4    -119.079903                    3                 3              1  ...
# ...          ...                  ...               ...            ...  ...
# 6583 -118.901544                    0                 1              1  ...
# 6584 -117.299644                    0                 4              1  ...
# 6585 -116.997260                    0                13              1  ...
# 6586 -120.954271                    1                22              1  ...
# 6587 -117.263628                    5                67              1  ...
#
#             Contract  Paperless Billing   Payment Method Monthly Charge  \
# 0           One Year                  1      Credit Card          65.60
# 1     Month-to-Month                  0      Credit Card          -4.00
# 2     Month-to-Month                  1  Bank Withdrawal          73.90
# 3     Month-to-Month                  1  Bank Withdrawal          98.00
# 4     Month-to-Month                  1      Credit Card          83.90
# ...              ...                ...              ...            ...
# 6583  Month-to-Month                  1      Credit Card          70.15
# 6584  Month-to-Month                  0  Bank Withdrawal          20.95
# 6585        One Year                  0      Credit Card          55.15
# 6586  Month-to-Month                  1  Bank Withdrawal          85.10
# 6587        Two Year                  0      Credit Card          67.85
#
#       Total Charges Total Refunds  Total Extra Data Charges  \
# 0            593.30          0.00                         0
# 1            542.40         38.33                        10
# 2            280.85          0.00                         0
# 3           1237.85          0.00                         0
# 4            267.40          0.00                         0
# ...             ...           ...                       ...
# 6583          70.15          0.00                         0
# 6584          85.50          0.00                         0
# 6585         742.90          0.00                         0
# 6586        1873.70          0.00                         0
# 6587        4627.65          0.00                         0
#
#       Total Long Distance Charges  Total Revenue  Customer Status
# 0                          381.51         974.81                1
# 1                           96.21         610.28                1
# 2                          134.60         415.45                0
# 3                          361.66        1599.51                0
# 4                           22.14         289.54                0
# ...                           ...            ...              ...
# 6583                        42.09         112.24                0
# 6584                         8.04          93.54                0
# 6585                       606.84        1349.74                1
# 6586                       356.40        2230.10                0
# 6587                       142.04        4769.69                1
#
# [5945 rows x 23 columns]

# %%
string_columns = data.select_dtypes(include=['object']).columns
string_columns
# Out:
# Index(['Gender', 'Contract', 'Payment Method'], dtype='object')

# %%
data = pd.get_dummies(data, drop_first=True, dtype=int)
data
# Out:
#       Age  Married  Number of Dependents  Zip Code   Latitude   Longitude  \
# 0      37        1                     0     93225  34.827662 -118.999073
# 1      46        0                     0     91206  34.162515 -118.203869
# 2      50        0                     0     92627  33.645672 -117.922613
# 3      78        1                     0     94553  38.014457 -122.115432
# 4      75        1                     0     93010  34.227846 -119.079903
# ...   ...      ...                   ...       ...        ...         ...
# 6583   53        0                     0     93628  36.807595 -118.901544
# 6584   36        0                     0     92028  33.362575 -117.299644
# 6585   20        0                     0     91941  32.759327 -116.997260
# 6586   40        1                     0     95367  37.734971 -120.954271
# 6587   21        1                     0     92075  33.001813 -117.263628
#
#       Number of Referrals  Tenure in Months  Phone Service  \
# 0                       2                 9              1
# 1                       0                 9              1
# 2                       0                 4              1
# 3                       1                13              1
# 4                       3                 3              1
# ...                   ...               ...            ...
# 6583                    0                 1              1
# 6584                    0                 4              1
# 6585                    0                13              1
# 6586                    1                22              1
# 6587                    5                67              1
#
#       Avg Monthly Long Distance Charges  ...  Total Refunds  \
# 0                                 42.39  ...           0.00
# 1                                 10.69  ...          38.33
# 2                                 33.65  ...           0.00
# 3                                 27.82  ...           0.00
# 4                                  7.38  ...           0.00
# ...                                 ...  ...            ...
# 6583                              42.09  ...           0.00
# 6584                               2.01  ...           0.00
# 6585                              46.68  ...           0.00
# 6586                              16.20  ...           0.00
# 6587                               2.12  ...           0.00
#
#       Total Extra Data Charges  Total Long Distance Charges  Total Revenue  \
# 0                            0                       381.51         974.81
# 1                           10                        96.21         610.28
# 2                            0                       134.60         415.45
# 3                            0                       361.66        1599.51
# 4                            0                        22.14         289.54
# ...                        ...                          ...            ...
# 6583                         0                        42.09         112.24
# 6584                         0                         8.04          93.54
# 6585                         0                       606.84        1349.74
# 6586                         0                       356.40        2230.10
# 6587                         0                       142.04        4769.69
#
#       Customer Status  Gender_Male  Contract_One Year  Contract_Two Year  \
# 0                   1            0                  1                  0
# 1                   1            1                  0                  0
# 2                   0            1                  0                  0
# 3                   0            1                  0                  0
# 4                   0            0                  0                  0
# ...               ...          ...                ...                ...
# 6583                0            0                  0                  0
# 6584                0            0                  0                  0
# 6585                1            0                  1                  0
# 6586                0            1                  0                  0
# 6587                1            1                  0                  1
#
#       Payment Method_Credit Card  Payment Method_Mailed Check
# 0                              1                            0
# 1                              1                            0
# 2                              0                            0
# 3                              0                            0
# 4                              1                            0
# ...                          ...                          ...
# 6583                           1                            0
# 6584                           0                            0
# 6585                           1                            0
# 6586                           0                            0
# 6587                           1                            0
#
# [5945 rows x 25 columns]

# %%
a = data['Customer Status']
data = data.drop('Customer Status',axis=1)
data = pd.concat([data,a], axis=1)

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=0)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
accuracy = accuracy_score(y_test, y_pred)
confusion_mat = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{confusion_mat}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.8643497757847534
# Confusion Matrix:
# [[ 404  111]
#  [ 131 1138]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       515
#            1       0.91      0.90      0.90      1269
#
#     accuracy                           0.86      1784
#    macro avg       0.83      0.84      0.84      1784
# weighted avg       0.87      0.86      0.87      1784
